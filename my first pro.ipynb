# %%
import pandas as pd
import numpy as np

# %%
file=r"C:/Users/temp/AppData/Local/Programs/Python/Python313/gym_members_exercise_tracking.csv"
dataset=pd.read_csv(file)
dataset
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Age                              0
# Gender                           0
# Weight (kg)                      0
# Height (m)                       0
# Max_BPM                          0
# Avg_BPM                          0
# Resting_BPM                      0
# Session_Duration (hours)         0
# Calories_Burned                  0
# Workout_Type                     0
# Fat_Percentage                   0
# Water_Intake (liters)            0
# Workout_Frequency (days/week)    0
# Experience_Level                 0
# BMI                              0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
la=LabelEncoder()
la.fit(dataset["Gender"])
dataset["Gender"]=la.transform(dataset["Gender"])

# %%
dataset
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56       1         88.3        1.71      180      157           60
# 1     46       0         74.9        1.53      179      151           66
# 2     32       0         68.1        1.66      167      122           54
# 3     25       1         53.2        1.70      190      164           56
# 4     38       1         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24       1         87.1        1.74      187      158           67
# 969   25       1         66.6        1.61      184      166           56
# 970   59       0         60.4        1.76      194      120           53
# 971   32       1        126.4        1.83      198      146           62
# 972   46       1         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 948 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            948 non-null    int64
#  1   Gender                         948 non-null    int64
#  2   Weight (kg)                    948 non-null    float64
#  3   Height (m)                     948 non-null    float64
#  4   Max_BPM                        948 non-null    int64
#  5   Avg_BPM                        948 non-null    int64
#  6   Resting_BPM                    948 non-null    int64
#  7   Session_Duration (hours)       948 non-null    float64
#  8   Calories_Burned                948 non-null    float64
#  9   Workout_Type                   948 non-null    object
#  10  Fat_Percentage                 948 non-null    float64
#  11  Water_Intake (liters)          948 non-null    float64
# ...

# %%
import seaborn as sns
import matplotlib as plt

# %%
sns.boxplot(x="Weight (kg)",data=dataset)
# Out:
# <Axes: xlabel='Weight (kg)'>

# %%
dataset.describe()
# Out:
#               Age      Gender  Weight (kg)  Height (m)     Max_BPM  \
# count  973.000000  973.000000   973.000000   973.00000  973.000000
# mean    38.683453    0.525180    73.854676     1.72258  179.883864
# std     12.180928    0.499622    21.207500     0.12772   11.525686
# min     18.000000    0.000000    40.000000     1.50000  160.000000
# 25%     28.000000    0.000000    58.100000     1.62000  170.000000
# 50%     40.000000    1.000000    70.000000     1.71000  180.000000
# 75%     49.000000    1.000000    86.000000     1.80000  190.000000
# max     59.000000    1.000000   129.900000     2.00000  199.000000
#
#           Avg_BPM  Resting_BPM  Session_Duration (hours)  Calories_Burned  \
# count  973.000000   973.000000                973.000000       973.000000
# mean   143.766701    62.223022                  1.256423       905.422405
# std     14.345101     7.327060                  0.343033       272.641516
# ...

# %%
sns.boxplot(x="Calories_Burned",data=dataset)
# Out:
# <Axes: xlabel='Calories_Burned'>

# %%
sns.boxplot(x="BMI",data=dataset)
# Out:
# <Axes: xlabel='BMI'>

# %%
q1=dataset["BMI"].quantile(0.25)
q3=dataset["BMI"].quantile(0.75)
iqr=q3-q1
min_range=q1-(1.5*iqr)
max_range=q3+(1.5*iqr)
dataset=dataset[dataset["BMI"]<=max_range]

# %%
dataset
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56       1         88.3        1.71      180      157           60
# 1     46       0         74.9        1.53      179      151           66
# 2     32       0         68.1        1.66      167      122           54
# 3     25       1         53.2        1.70      190      164           56
# 4     38       1         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24       1         87.1        1.74      187      158           67
# 969   25       1         66.6        1.61      184      166           56
# 970   59       0         60.4        1.76      194      120           53
# 971   32       1        126.4        1.83      198      146           62
# 972   46       1         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
sns.boxplot(x="BMI",data=dataset)
# Out:
# <Axes: xlabel='BMI'>

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 948 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            948 non-null    int64
#  1   Gender                         948 non-null    int64
#  2   Weight (kg)                    948 non-null    float64
#  3   Height (m)                     948 non-null    float64
#  4   Max_BPM                        948 non-null    int64
#  5   Avg_BPM                        948 non-null    int64
#  6   Resting_BPM                    948 non-null    int64
#  7   Session_Duration (hours)       948 non-null    float64
#  8   Calories_Burned                948 non-null    float64
#  9   Workout_Type                   948 non-null    object
#  10  Fat_Percentage                 948 non-null    float64
#  11  Water_Intake (liters)          948 non-null    float64
# ...

# %%
q1=dataset["Calories_Burned"].quantile(0.25)
q3=dataset["Calories_Burned"].quantile(0.75)
iqr=q3-q1
min_range=q1-(1.5*iqr)
max_range=q3+(1.5*iqr)
dataset=dataset[dataset["Calories_Burned"]<=max_range]

# %%
sns.boxplot(x="Calories_Burned",data=dataset)
# Out:
# <Axes: xlabel='Calories_Burned'>

# %%
q1=dataset["Weight (kg)"].quantile(0.25)
q3=dataset["Weight (kg)"].quantile(0.75)
iqr=q3-q1
min_range=q1-(1.5*iqr)
max_range=q3+(1.5*iqr)
dataset=dataset[dataset["Weight (kg)"]<=max_range]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 922 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            922 non-null    int64
#  1   Gender                         922 non-null    int64
#  2   Weight (kg)                    922 non-null    float64
#  3   Height (m)                     922 non-null    float64
#  4   Max_BPM                        922 non-null    int64
#  5   Avg_BPM                        922 non-null    int64
#  6   Resting_BPM                    922 non-null    int64
#  7   Session_Duration (hours)       922 non-null    float64
#  8   Calories_Burned                922 non-null    float64
#  9   Workout_Type                   922 non-null    object
#  10  Fat_Percentage                 922 non-null    float64
#  11  Water_Intake (liters)          922 non-null    float64
# ...

# %%
pf=pd.DataFrame(dataset)
pf.drop_duplicates()
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56       1         88.3        1.71      180      157           60
# 1     46       0         74.9        1.53      179      151           66
# 2     32       0         68.1        1.66      167      122           54
# 3     25       1         53.2        1.70      190      164           56
# 4     38       1         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 967   20       1         55.0        1.60      172      168           67
# 968   24       1         87.1        1.74      187      158           67
# 969   25       1         66.6        1.61      184      166           56
# 970   59       0         60.4        1.76      194      120           53
# 972   46       1         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
dataset.Workout_Type.unique()
# Out:
# array(['Yoga', 'HIIT', 'Cardio', 'Strength'], dtype=object)

# %%
ord_data=[['Yoga', 'HIIT', 'Cardio', 'Strength']]
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder(categories=ord_data)
oe.fit(dataset[["Workout_Type"]])
t=oe.transform(dataset[["Workout_Type"]])
dataset["Workout"]=t
print(dataset)
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56       1         88.3        1.71      180      157           60
# 1     46       0         74.9        1.53      179      151           66
# 2     32       0         68.1        1.66      167      122           54
# 3     25       1         53.2        1.70      190      164           56
# 4     38       1         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 967   20       1         55.0        1.60      172      168           67
# 968   24       1         87.1        1.74      187      158           67
# 969   25       1         66.6        1.61      184      166           56
# 970   59       0         60.4        1.76      194      120           53
# 972   46       1         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
output_data=dataset["Calories_Burned"]
input_data1=dataset.iloc[ : , :-1]

# %%
dataset.drop(columns=["Workout_Type"],inplace=True)
dataset
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56       1         88.3        1.71      180      157           60
# 1     46       0         74.9        1.53      179      151           66
# 2     32       0         68.1        1.66      167      122           54
# 3     25       1         53.2        1.70      190      164           56
# 4     38       1         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 967   20       1         55.0        1.60      172      168           67
# 968   24       1         87.1        1.74      187      158           67
# 969   25       1         66.6        1.61      184      166           56
# 970   59       0         60.4        1.76      194      120           53
# 972   46       1         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# ...

# %%
dataset["Calories_Burned"]=dataset.pop("Calories_Burned")
dataset
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56       1         88.3        1.71      180      157           60
# 1     46       0         74.9        1.53      179      151           66
# 2     32       0         68.1        1.66      167      122           54
# 3     25       1         53.2        1.70      190      164           56
# 4     38       1         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 967   20       1         55.0        1.60      172      168           67
# 968   24       1         87.1        1.74      187      158           67
# 969   25       1         66.6        1.61      184      166           56
# 970   59       0         60.4        1.76      194      120           53
# 972   46       1         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Fat_Percentage  Water_Intake (liters)  \
# ...

# %%
sns.pairplot(data=dataset)
plt.show()
sns.heatmap(data=dataset.corr(),annot=True)

# %%
y=dataset["Calories_Burned"]
x=dataset.iloc[ : , :-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
x
# Out:
# [     Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM
#  0     56       1         88.3        1.71      180      157           60
#  1     46       0         74.9        1.53      179      151           66
#  2     32       0         68.1        1.66      167      122           54
#  3     25       1         53.2        1.70      190      164           56
#  4     38       1         46.1        1.79      188      158           68
#  ..   ...     ...          ...         ...      ...      ...          ...
#  967   20       1         55.0        1.60      172      168           67
#  968   24       1         87.1        1.74      187      158           67
#  969   25       1         66.6        1.61      184      166           56
#  970   59       0         60.4        1.76      194      120           53
#  972   46       1         88.7        1.63      166      146           66
#
#  [922 rows x 7 columns],
# ...

# %%
y
# Out:
# 0      1313.0
# 1       883.0
# 2       677.0
# 3       532.0
# 4       556.0
#         ...
# 967    1035.0
# 968    1364.0
# 969    1260.0
# 970     929.0
# 972     542.0
# Name: Calories_Burned, Length: 922, dtype: float64

# %%
print(x.shape)
# Out:
# (922, 14)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9783685170421349
