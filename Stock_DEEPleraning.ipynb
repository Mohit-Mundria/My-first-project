# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohit-Mundria/My-first-project/blob/main/Stock_DEEPleraning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv('/content/sample_data/Combined_Stocks.csv')
dataset.head(5)
# Out:
#        Date      Symbol Series  Prev Close    Open     High    Low   Last  \
# 0  27.11.07  ADANIPORTS     EQ      440.00  770.00  1050.00  770.0  959.0
# 1  28.11.07  ADANIPORTS     EQ      962.90  984.00   990.00  874.0  885.0
# 2  29.11.07  ADANIPORTS     EQ      893.90  909.00   914.75  841.0  887.0
# 3  30.11.07  ADANIPORTS     EQ      884.20  890.00   958.00  890.0  929.0
# 4   3.12.07  ADANIPORTS     EQ      921.55  939.75   995.00  922.0  980.0
#
#     Close    VWAP      Volume      Turnover  Deliverable Volume  %Deliverble
# 0  962.90  984.72  27294366.0  2.690000e+15           9859619.0       0.3612
# 1  893.90  941.38   4581338.0  4.310000e+14           1453278.0       0.3172
# 2  884.20  888.09   5124121.0  4.550000e+14           1069678.0       0.2088
# 3  921.55  929.17   4609762.0  4.280000e+14           1260913.0       0.2735
# 4  969.30  965.65   2977470.0  2.880000e+14            816123.0       0.2741

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168743 entries, 0 to 168742
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                168743 non-null  object
#  1   Symbol              168743 non-null  object
#  2   Series              168743 non-null  object
#  3   Prev Close          168743 non-null  float64
#  4   Open                168743 non-null  float64
#  5   High                168743 non-null  float64
#  6   Low                 168743 non-null  float64
#  7   Last                168742 non-null  float64
#  8   Close               168742 non-null  float64
#  9   VWAP                168742 non-null  float64
#  10  Volume              168742 non-null  float64
#  11  Turnover            168742 non-null  float64
#  12  Deliverable Volume  156989 non-null  float64
#  13  %Deliverble         156989 non-null  float64
# dtypes: float64(11), object(3)
# memory usage: 18.0+ MB

# %%
dataset.describe()
# Out:
#           Prev Close           Open           High            Low  \
# count  168743.000000  168743.000000  168743.000000  168743.000000
# mean     1320.928488    1322.432981    1341.436092    1301.941679
# std      2513.045709    2517.057553    2548.262449    2480.859196
# min         0.000000       8.500000       9.750000       8.500000
# 25%       310.550000     310.800000     315.900000     305.275000
# 50%       637.650000     638.750000     649.000000     626.600000
# 75%      1360.800000    1361.425000    1380.000000    1342.050000
# max     32861.950000   33399.950000   33480.000000   32468.100000
#
#                 Last          Close           VWAP        Volume  \
# count  168742.000000  168742.000000  168742.000000  1.687420e+05
# mean     1321.093004    1321.216379    1321.808275  2.367878e+06
# std      2512.718110    2513.288414    2514.188124  5.399250e+06
# min         9.100000       9.150000       9.210000  3.000000e+00
# ...

# %%
dataset.isnull().sum()
# Out:
# Date                      0
# Symbol                    0
# Series                    0
# Prev Close                0
# Open                      0
# High                      0
# Low                       0
# Last                      1
# Close                     1
# VWAP                      1
# Volume                    1
# Turnover                  1
# Deliverable Volume    11754
# %Deliverble           11754
# dtype: int64

# %%
dataset.drop(columns=["Deliverable Volume"],inplace=True)

# %%
dataset.drop(columns=["%Deliverble"],inplace=True)

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Date          0
# Symbol        0
# Series        0
# Prev Close    0
# Open          0
# High          0
# Low           0
# Last          0
# Close         0
# VWAP          0
# Volume        0
# Turnover      0
# dtype: int64

# %%
grp_list=(dataset.groupby("Symbol"))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(5,len(dataset.columns)*3))
for i,column in enumerate(dataset.columns,1):
   plt.subplot(len(dataset.columns),1,i)
   sns.boxplot(x=dataset[column])
   plt.title(f"Boxplot for {column}")
plt.tight_layout()
plt.show()

# %%
ord={'ADANIPORTS':0, 'ASIANPAINT':1, 'UTIBANK':2, 'AXISBANK':3, 'BAJAJ-AUTO':4,
       'BAJAJFINSV':5, 'BAJAUTOFIN':6, 'BAJFINANCE':7, 'BHARTI':8, 'BHARTIARTL':9,
       'BPCL':10, 'BRITANNIA':11, 'CIPLA':12, 'COALINDIA':13, 'DRREDDY':14, 'EICHERMOT':15,
       'GAIL':16, 'GRASIM':17, 'HCLTECH':18, 'HDFC':19, 'HDFCBANK':20, 'HEROHONDA':21,
       'HEROMOTOCO':22, 'HINDALC0':23, 'HINDALCO':24, 'HINDLEVER':25, 'HINDUNILVR':26,
       'ICICIBANK':27, 'INDUSINDBK':28, 'INFOSYSTCH':29, 'INFY':30, 'IOC':31, 'ITC':32,
       'JSWSTL':33, 'JSWSTEEL':34, 'KOTAKMAH':35, 'KOTAKBANK':36, 'LT':37, 'MARUTI':38,
       'M&M':39, 'NESTLEIND':40, 'NTPC':41, 'ONGC':42, 'POWERGRID':43, 'RELIANCE':44,
       'SBIN':45, 'SHREECEM':46, 'SUNPHARMA':47, 'TELCO':48, 'TATAMOTORS':49, 'TISCO':50,
       'TATASTEEL':51, 'TCS':52, 'TECHM':53, 'TITAN':54, 'ULTRACEMCO':55, 'UNIPHOS':56,
       'UPL':57, 'SESAGOA':58, 'SSLT':59, 'VEDL':60, 'WIPRO':61, 'ZEETELE':62, 'ZEEL':63}
t=dataset["Symbol"].map(ord)
dataset["Symbol_encoded"]=t
dataset.drop(columns=["Symbol"],inplace=True)
dataset
# Out:
#             Date Series  Prev Close     Open     High      Low     Last  \
# 0       27.11.07     EQ      440.00   770.00  1050.00   770.00   959.00
# 1       28.11.07     EQ      962.90   984.00   990.00   874.00   885.00
# 2       29.11.07     EQ      893.90   909.00   914.75   841.00   887.00
# 3       30.11.07     EQ      884.20   890.00   958.00   890.00   929.00
# 4        3.12.07     EQ      921.55   939.75   995.00   922.00   980.00
# ...          ...    ...         ...      ...      ...      ...      ...
# 168737   22.8.13     EQ     1734.50  1725.00  1794.00  1702.00  1769.00
# 168738   23.8.13     EQ     1776.70  1776.00  1796.95  1753.25  1777.00
# 168739   26.8.13     EQ     1779.60  1788.00  1817.85  1752.50  1780.00
# 168740   27.8.13     EQ     1780.65  1762.00  1782.75  1701.25  1735.25
# 168741   28.8.13     EQ     1727.75  1710.00  1744.35  1680.05  1724.00
#
#           Close     VWAP      Volume      Turnover  Symbol_encoded
# ...

# %%
splitted = dataset['Date'].str.split('.', expand=True)

dataset['Day'] = splitted[0].astype('int')
dataset['Month'] = splitted[1].astype('int')
dataset['Year'] = splitted[2].astype('int')

dataset.head()
# Out:
#        Date Series  Prev Close    Open     High    Low   Last   Close    VWAP  \
# 0  27.11.07     EQ      440.00  770.00  1050.00  770.0  959.0  962.90  984.72
# 1  28.11.07     EQ      962.90  984.00   990.00  874.0  885.0  893.90  941.38
# 2  29.11.07     EQ      893.90  909.00   914.75  841.0  887.0  884.20  888.09
# 3  30.11.07     EQ      884.20  890.00   958.00  890.0  929.0  921.55  929.17
# 4   3.12.07     EQ      921.55  939.75   995.00  922.0  980.0  969.30  965.65
#
#        Volume      Turnover  Symbol_encoded  Day  Month  Year
# 0  27294366.0  2.690000e+15               0   27     11     7
# 1   4581338.0  4.310000e+14               0   28     11     7
# 2   5124121.0  4.550000e+14               0   29     11     7
# 3   4609762.0  4.280000e+14               0   30     11     7
# 4   2977470.0  2.880000e+14               0    3     12     7

# %%
dataset.drop("Date",inplace=True,axis=1)
dataset.drop("Series",inplace=True,axis=1)
dataset.drop("Last",inplace=True,axis=1)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
features=dataset[["Prev Close","Open","High","Low","VWAP","Volume","Turnover"]]
target=dataset[["Close"]]
features_scaled=ss.fit_transform(features)
target_scaled=ss.fit_transform(target)
dataset.loc[:, features.columns] = features_scaled
dataset.to_csv('Combined_Stock.csv', index=True)
dataset
# Out:
#         Prev Close      Open      High       Low    Close      VWAP    Volume  \
# 0        -0.350541 -0.219475 -0.114366 -0.214421   962.90 -0.134075  4.616671
# 1        -0.142467 -0.134455 -0.137911 -0.172500   893.90 -0.151313  0.409958
# 2        -0.169924 -0.164252 -0.167441 -0.185802   884.20 -0.172509  0.510488
# 3        -0.173784 -0.171800 -0.150469 -0.166051   921.55 -0.156169  0.415223
# 4        -0.158921 -0.152035 -0.135949 -0.153152   969.30 -0.141660  0.112903
# ...            ...       ...       ...       ...      ...       ...       ...
# 168737    0.164571  0.159937  0.177598  0.161255  1776.70  0.168811 -0.362644
# 168738    0.181363  0.180198  0.178756  0.181914  1779.60  0.180795 -0.391594
# 168739    0.182517  0.184966  0.186957  0.181611  1780.65  0.184964 -0.402079
# 168740    0.182935  0.174636  0.173183  0.160953  1727.75  0.170911 -0.358677
# 168741    0.161885  0.153977  0.158114  0.152408  1727.75  0.155184 -0.353861
#
# ...

# %%
from sklearn.model_selection import train_test_split
x=dataset.drop("Close",axis=1)
y=dataset["Close"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
dataset.corr()
# Out:
#                 Prev Close      Open      High       Low     Close      VWAP  \
# Prev Close        1.000000  0.999625  0.999525  0.999505  0.999417  0.999527
# Open              0.999625  1.000000  0.999862  0.999861  0.999757  0.999869
# High              0.999525  0.999862  1.000000  0.999794  0.999888  0.999937
# Low               0.999505  0.999861  0.999794  1.000000  0.999880  0.999932
# Close             0.999417  0.999757  0.999888  0.999880  1.000000  0.999962
# VWAP              0.999527  0.999869  0.999937  0.999932  0.999962  1.000000
# Volume           -0.120776 -0.120817 -0.120567 -0.121045 -0.120753 -0.120811
# Turnover          0.084045  0.083764  0.085136  0.082957  0.084294  0.084143
# Symbol_encoded    0.066980  0.066987  0.066769  0.067161  0.066976  0.066964
# Day              -0.000634 -0.000706 -0.000631 -0.000760 -0.000656 -0.000703
# Month            -0.001201 -0.001229 -0.001402 -0.000867 -0.001065 -0.001100
# ...

# %%
from sklearn import set_config
set_config(display="text")

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

# %%
model.add(Dense(10,activation='linear',input_dim=11))
model.add(Dense(8,activation='linear'))
model.add(Dense(6,activation='linear'))
model.add(Dense(4,activation='linear'))
model.add(Dense(1,activation='linear'))
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 10)                  │             120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │              88 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
model.compile(loss='MeanSquaredError',optimizer='Adam')
model.fit(x_train,y_train,epochs=50,validation_split=0.2)
# Out:
# Epoch 1/50
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - loss: 23429.4277 - val_loss: 1907.3142
# Epoch 2/50
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 2863.3328 - val_loss: 581.0273
# Epoch 3/50
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2151.5366 - val_loss: 666.6749
# Epoch 4/50
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 2500.9360 - val_loss: 749.3881
# Epoch 5/50
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 1721.4338 - val_loss: 2077.9126
# Epoch 6/50
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - loss: 1887.1216 - val_loss: 773.4799
# Epoch 7/50
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 1549.9725 - val_loss: 802.8422
# Epoch 8/50
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2065.0461 - val_loss: 1203.6661
# Epoch 9/50
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 1953.9583 - val_loss: 675.1466
# Epoch 10/50
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 2091.6018 - val_loss: 1680.1322
# Epoch 11/50
# ...

# %%
y_pred=model.predict(x_test)
from sklearn.metrics import r2_score
# Out:
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(mse)
print(r2)
# Out:
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 2775.6913455332065
# 0.9995382354646563

# %%
import joblib
joblib.dump(model,"Deep_learning_Stock_Prediction")
joblib.dump(ss,"StandardScaler")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c4fb59cbfa22> in <cell line: 0>()
#       1 import joblib
# ----> 2 joblib.dump(model,"Deep_learning_Stock_Prediction")
#       3 joblib.dump(ss,"StandardScaler")
#
# NameError: name 'model' is not defined
